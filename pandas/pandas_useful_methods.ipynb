# %%
import numpy as np
import pandas as pd

# %%
tips = pd.read_csv('tips.csv')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Apply on a Single Column

# %%
# Create function to apply to dataframe

def cc_last_4(number):
    
    last_4 = str(number)[-4:]
    return int(last_4)

# %%
# Test function

cc_last_4(1239872398471908237)
# Out:
# 8237

# %%
# Apply function to specific feature for desired results

tips['last_4_cc'] = tips['CC Number'].apply(cc_last_4)

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_4_cc
# 0  Christy Cunningham  3560325168603410    Sun2959       3410
# 1      Douglas Tucker  4478071379779230    Sun4608       9230
# 2      Travis Walters  6011812112971322    Sun4458       1322
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994
# 4        Tonya Carter  4832732618637221    Sun2251       7221

# %% [markdown]
# # Apply on Multiple Columns

# %%
# Write a function that takes multiple features as an argument

def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
# Call the function on the dataframe using the lambda method

tips[['total_bill', 'tip']].apply(lambda tips: quality(tips['total_bill'], tips['tip']), axis = 1)
# Out:
# 0      Other
# 1      Other
# 2      Other
# 3      Other
# 4      Other
#        ...
# 239    Other
# 240    Other
# 241    Other
# 242    Other
# 243    Other
# Length: 244, dtype: object

# %%
# Assign the output to a new feature

tips['quality'] = tips[['total_bill', 'tip']].apply(lambda tips: quality(tips['total_bill'], tips['tip']), axis = 1)

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_4_cc quality
# 0  Christy Cunningham  3560325168603410    Sun2959       3410   Other
# 1      Douglas Tucker  4478071379779230    Sun4608       9230   Other
# 2      Travis Walters  6011812112971322    Sun4458       1322   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994   Other
# 4        Tonya Carter  4832732618637221    Sun2251       7221   Other

# %%
# You may also use .vectorize()

tips['quality'] = np.vectorize(quality)(tips['total_bill'], tips['tip'])

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_4_cc quality
# 0  Christy Cunningham  3560325168603410    Sun2959       3410   Other
# 1      Douglas Tucker  4478071379779230    Sun4608       9230   Other
# 2      Travis Walters  6011812112971322    Sun4458       1322   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994   Other
# 4        Tonya Carter  4832732618637221    Sun2251       7221   Other

# %% [markdown]
# # Statistical Information and Sorting

# %%
tips = pd.read_csv('tips.csv')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# The .sort_values() function will allow you to rearrange the dataframe to display in order on a feature

tips.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
## The default order is lowest to highest, but it can be specified manually if desired

tips.sort_values('tip', ascending = False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# Features can be sorted to see the highest and lowest values and their locations

tips.total_bill.max()
# Out:
# 50.81

# %%
tips.total_bill.idxmax()
# Out:
# 170

# %%
tips.iloc[170]
# Out:
# total_bill                     50.81
# tip                               10
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
tips.total_bill.min()
# Out:
# 3.07

# %%
tips.total_bill.idxmin()
# Out:
# 67

# %%
tips.iloc[tips.total_bill.idxmin()]
# Out:
# total_bill                      3.07
# tip                                1
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
# The .corr() function will return a table indicating the linear correlation of all numerical data

tips.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
# The .value_counts() can show you the distribution of values in your categorical features

tips.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
# The .unique() will list all the unique values in a feature

tips['Payer Name'].unique()
# Out:
# array(['Christy Cunningham', 'Douglas Tucker', 'Travis Walters',
#        'Nathaniel Harris', 'Tonya Carter', 'Erik Smith',
#        'Kristopher Johnson', 'Robert Buck', 'Joseph Mcdonald',
#        'Jerome Abbott', 'William Riley', 'Diane Macias',
#        'Chad Harrington', 'Joshua Jones', 'Vanessa Jones',
#        'Matthew Reilly', 'Elizabeth Foster', 'John Pittman',
#        'Laura Martinez', 'Timothy Oneal', 'Thomas Rice',
#        'Natalie Gardner', 'Ashley Shelton', 'Lance Peterson',
#        'Christopher Ross', 'Robert Perkins', 'Kyle Avery',
#        'Patrick Barber', 'David Collier', 'Melinda Murphy', 'Grant Hall',
#        'Danny Santiago', 'Amanda Wilson', 'Amber Francis',
#        'Jacob Castillo', 'Joseph Mullins', 'William Ford', 'Erin Lewis',
#        'Brandon Bradley', 'Mr. Brandon Berry', 'Adam Edwards',
#        'David Boyer', 'Bryan Brown', 'Christopher Spears', 'Todd Cooper',
#        'Richard Fitzgerald', 'Joshua Gilmore', 'James Barnes',
# ...

# %%
# While .nunique() will tell you how many values there are

tips['Payer Name'].nunique()
# Out:
# 244

# %%
# The .replace() function can be used to replace values if you prefer

tips.sex.replace('Female', 'f')
# Out:
# 0         f
# 1      Male
# 2      Male
# 3      Male
# 4         f
#        ...
# 239    Male
# 240       f
# 241    Male
# 242    Male
# 243       f
# Name: sex, Length: 244, dtype: object

# %%
tips.sex.replace(['Female', 'Male'], ['f', 'm'])
# Out:
# 0      f
# 1      m
# 2      m
# 3      m
# 4      f
#       ..
# 239    m
# 240    f
# 241    m
# 242    m
# 243    f
# Name: sex, Length: 244, dtype: object

# %%
# The .sample() function will return a a specifed amount of random observations from the dataframe

tips.sample(5)
# Out:
#      total_bill  tip     sex smoker   day    time  size  price_per_person  \
# 236       12.60  1.0    Male    Yes   Sat  Dinner     2              6.30
# 184       40.55  3.0    Male    Yes   Sun  Dinner     2             20.27
# 140       17.47  3.5  Female     No  Thur   Lunch     2              8.74
# 204       20.53  4.0    Male    Yes  Thur   Lunch     4              5.13
# 149        7.51  2.0    Male     No  Thur   Lunch     2              3.76
#
#          Payer Name         CC Number Payment ID
# 236   Matthew Myers  3543676378973965    Sat5032
# 184     Stephen Cox  3547798222044029    Sun5140
# 140      Kayla Rios  5233918213804470   Thur3906
# 204       Scott Kim  3570611756827620   Thur2160
# 149  Daniel Robbins  4823139288341889   Thur6321

# %%
tips.sample(5)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 9         14.78   3.23    Male     No   Sun  Dinner     2              7.39
# 104       20.92   4.08  Female     No   Sat  Dinner     2             10.46
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 138       16.00   2.00    Male    Yes  Thur   Lunch     2              8.00
# 55        19.49   3.51    Male     No   Sun  Dinner     2              9.74
#
#               Payer Name         CC Number Payment ID
# 9          Jerome Abbott  3532124519049786    Sun3775
# 104  Gabrielle Frederick  4013010878990106    Sat3194
# 170        Gregory Clark  5473850968388236    Sat1954
# 138        Jason Burgess  3561461821942363   Thur2710
# 55      Michael Hamilton  6502227786581768    Sun1118
